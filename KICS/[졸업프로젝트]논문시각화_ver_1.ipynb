# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# 졸업논문에서 작성한 FL 값 (10개)
#acc_fd = [0.655400, 0.657873, 0.676010, 0.700742, 0.777411, 0.790602, 0.800495, 0.803792, 0.804617, 0.805441]
#loss_fd = [2.135458, 1.439673, 1.094696, 0.973483, 0.905005, 0.856158, 0.818512, 0.792516, 0.774349, 0.761186]

# 졸업논문에서 작성한 FL+DP 값 (20개)
acc_fd_dp = [0.624897, 0.661171, 0.638087, 0.662819, 0.684254, 0.691674, 0.799670, 0.801319, 0.773289, 0.769992, 0.789777, 0.767519, 0.792251, 0.787304, 0.801319, 0.72465, 0.800495, 0.790602, 0.801319, 0.807090]
loss_fd_dp = [1.967384, 1.765698, 1.767950, 1.477620, 1.027212, 1.037482, 0.917180, 0.925493, 1.362558, 1.556252, 1.189343, 1.292304, 1.045923, 0.897034, 0.932219, 1.279750, 0.94483, 0.890658, 0.888937, 0.789528]

# %%
# 새로 구한 FL 값 (20개)
acc_fd = []
loss_fd = []
fd = [[2.161668539047241, 0.7065127491950989],[1.4466949701309204, 0.7056883573532104], [1.0639042854309082, 0.7073372006416321], [0.9368425607681274, 0.7098103761672974], [0.8628708720207214, 0.7403132915496826],[0.8148763179779053, 0.7881286144256592],[0.781308650970459, 0.8046166300773621],[0.7564736008644104, 0.8079142570495605],[0.7377761006355286, 0.811211884021759],[0.7236965298652649, 0.8103874921798706],[0.7135012745857239, 0.8136850595474243],[0.706122875213623, 0.815333902835846],[0.7006826996803284, 0.8161582946777344],[0.6966835260391235, 0.8186314702033997],[0.6936790347099304, 0.8186314702033997],[0.6914451122283936, 0.8202803134918213],[0.6898991465568542, 0.823577880859375],[0.6889191269874573, 0.8252267241477966],[0.6883507966995239, 0.8252267241477966],[0.6881399154663086, 0.8252267241477966]]
for i in range(20):
    loss_fd.append(fd[i][0])
    acc_fd.append(fd[i][1])

# %%
# 새로 구한 FL+DP 값 (20개) 
#acc_fd_dp = []
#loss_fd_dp = []

'''
시간이 오래 걸림 (일단 있는거 사용)
'''

# %%
# 생각이 안나서...

epoch = [i for i in range(10,210,10)]
epochs = [i for i in range(0,210,10)]
high = [0.893,0.893,0.893,0.893,0.893,0.893,0.893,0.893,0.893,0.893,0.893,0.893,0.893,0.893,0.893,0.893,0.893,0.893,0.893,0.893,0.893]
low= [0.286,0.286,0.286,0.286,0.286,0.286,0.286,0.286,0.286,0.286,0.286,0.286,0.286,0.286,0.286,0.286,0.286,0.286,0.286,0.286,0.286]

# %%
plt.plot(epoch,acc_fd, 'c^-', label='FL') # drawstyle='steps-post'
plt.plot(epoch,acc_fd_dp, 'ro-', label='DP+FL')
plt.plot(epochs,high,'m--')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.axis([0, 200, 0.5, 1.0])
plt.show()

# %%
plt.plot(epoch,loss_fd, 'c^-',label='FL')
plt.plot(epoch,loss_fd_dp, 'ro-',label='DP+FL')
plt.plot(epochs,low,'m--')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.axis([0, 200, 0.0, 2.5])
plt.show()
