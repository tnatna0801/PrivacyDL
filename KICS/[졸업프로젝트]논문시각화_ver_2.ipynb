,[0.9616304636001587, 0.8120362758636475],[0.9142405986785889, 0.8128606677055359]
,[1.1254911422729492, 0.8120362758636475],[0.6996204257011414, 0.8219290971755981]
,[0.7839447855949402, 0.8128606677055359],[0.7728926539421082, 0.815333902835846]]
len(new_fd_3), len(new_dp_fd_3)

loss_fd_3 = []
acc_fd_3 = []
loss_dp_fd_3 = []
acc_dp_fd_3 = []
for i in range(20):
    loss_fd_3.append(new_fd_3[i][0])
    acc_fd_3.append(new_fd_3[i][1])
    loss_dp_fd_3.append(new_dp_fd_3[i][0])
    acc_dp_fd_3.append(new_dp_fd_3[i][1])

# %%
new_fd_4 = [
[2.047178030014038, 0.6784831285476685]
,[1.3490923643112183, 0.6793075203895569]
,[1.0361437797546387, 0.6834295392036438]
,[0.9217935800552368, 0.6867271065711975]
,[0.8528098464012146, 0.7708161473274231]
,[0.8096289038658142, 0.8070898652076721]
,[0.7766706347465515, 0.808738648891449]
,[0.7521502375602722, 0.8136850595474243]
,[0.7339357733726501, 0.8136850595474243]
,[0.7205060124397278, 0.8145094513893127]
,[0.710448145866394, 0.8178070783615112]
,[0.7027034163475037, 0.8219290971755981]
,[0.6966703534126282, 0.823577880859375]
,[0.6919416785240173, 0.8244023323059082]
,[0.6881508231163025, 0.823577880859375]
,[0.6850996017456055, 0.8219290971755981]
,[0.6826655864715576, 0.8202803134918213]
,[0.6807481646537781, 0.8211047053337097]
,[0.6791436672210693, 0.8219290971755981]
,[0.6777895092964172, 0.823577880859375]]
new_dp_fd_4 = [[1.9836621284484863, 0.668590247631073],[1.5577046871185303, 0.6677658557891846],[1.262522578239441, 0.6784831285476685],
[1.2478834390640259, 0.6702390909194946],[1.2074997425079346, 0.7551525235176086],[0.9825469851493835, 0.7320692539215088],
[0.8300963640213013, 0.808738648891449],[1.1014310121536255, 0.8145094513893127],[1.6807140111923218, 0.7757625579833984],
[0.9932665228843689, 0.8079142570495605],[0.7684882879257202, 0.808738648891449],[0.9014157652854919, 0.8103874921798706],
[0.9571588635444641, 0.8070898652076721],[1.1716450452804565, 0.8054410815238953],[0.9411329030990601, 0.8128606677055359],
[0.9669655561447144, 0.815333902835846],[1.0125480890274048, 0.8145094513893127],[0.9698060750961304, 0.8128606677055359],
[1.0460759401321411, 0.811211884021759],[1.1208844184875488, 0.7856553792953491]]
loss_fd_4 = []
acc_fd_4 = []
loss_dp_fd_4 = []
acc_dp_fd_4 = []
for i in range(20):
    loss_fd_4.append(new_fd_4[i][0])
    acc_fd_4.append(new_fd_4[i][1])
    loss_dp_fd_4.append(new_dp_fd_4[i][0])
    acc_dp_fd_4.append(new_dp_fd_4[i][1])

# %%
# 졸업논문에서 작성한 FL 값 (10개)
#acc_fd = [0.655400, 0.657873, 0.676010, 0.700742, 0.777411, 0.790602, 0.800495, 0.803792, 0.804617, 0.805441]
#loss_fd = [2.135458, 1.439673, 1.094696, 0.973483, 0.905005, 0.856158, 0.818512, 0.792516, 0.774349, 0.761186]

# 졸업논문에서 작성한 FL+DP 값 (20개)
acc_dp_fd_5 = [0.624897, 0.661171, 0.638087, 0.662819, 0.684254, 0.691674, 0.799670, 0.801319, 0.773289, 0.769992, 0.789777, 0.767519, 0.792251, 0.787304, 0.801319, 0.72465, 0.800495, 0.790602, 0.801319, 0.807090]
loss_dp_fd_5 = [1.967384, 1.765698, 1.767950, 1.477620, 1.027212, 1.037482, 0.917180, 0.925493, 1.362558, 1.556252, 1.189343, 1.292304, 1.045923, 0.897034, 0.932219, 1.279750, 0.94483, 0.890658, 0.888937, 0.789528]

# 새로 구한 FL 값 (20개)
acc_fd_5 = []
loss_fd_5 = []
fd = [[2.161668539047241, 0.7065127491950989],[1.4466949701309204, 0.7056883573532104], [1.0639042854309082, 0.7073372006416321], [0.9368425607681274, 0.7098103761672974], [0.8628708720207214, 0.7403132915496826],[0.8148763179779053, 0.7881286144256592],[0.781308650970459, 0.8046166300773621],[0.7564736008644104, 0.8079142570495605],[0.7377761006355286, 0.811211884021759],[0.7236965298652649, 0.8103874921798706],[0.7135012745857239, 0.8136850595474243],[0.706122875213623, 0.815333902835846],[0.7006826996803284, 0.8161582946777344],[0.6966835260391235, 0.8186314702033997],[0.6936790347099304, 0.8186314702033997],[0.6914451122283936, 0.8202803134918213],[0.6898991465568542, 0.823577880859375],[0.6889191269874573, 0.8252267241477966],[0.6883507966995239, 0.8252267241477966],[0.6881399154663086, 0.8252267241477966]]
for i in range(20):
    loss_fd_5.append(fd[i][0])
    acc_fd_5.append(fd[i][1])

# %%
df1 = pd.DataFrame({'acc':acc_fd_1,'event':['acc']*20,'region':['fd']*20, 'epoch':[i for i in range(10,210,10)]})
df2 = pd.DataFrame({'acc':acc_fd_2,'event':['acc']*20,'region':['fd']*20, 'epoch':[i for i in range(10,210,10)]})
df3 = pd.DataFrame({'acc':acc_fd_3,'event':['acc']*20,'region':['fd']*20, 'epoch':[i for i in range(10,210,10)]})
df4 = pd.DataFrame({'acc':acc_fd_4,'event':['acc']*20,'region':['fd']*20, 'epoch':[i for i in range(10,210,10)]})
df5 = pd.DataFrame({'acc':acc_fd_5,'event':['acc']*20,'region':['fd']*20, 'epoch':[i for i in range(10,210,10)]})

df6 = pd.DataFrame({'loss':loss_fd_1,'event':['loss']*20,'region':['fd']*20, 'epoch':[i for i in range(10,210,10)]})
df7 = pd.DataFrame({'loss':loss_fd_2,'event':['loss']*20,'region':['fd']*20, 'epoch':[i for i in range(10,210,10)]})
df8 = pd.DataFrame({'loss':loss_fd_3,'event':['loss']*20,'region':['fd']*20, 'epoch':[i for i in range(10,210,10)]})
df9 = pd.DataFrame({'loss':loss_fd_4,'event':['loss']*20,'region':['fd']*20, 'epoch':[i for i in range(10,210,10)]})
df10 = pd.DataFrame({'loss':loss_fd_5,'event':['loss']*20,'region':['fd']*20, 'epoch':[i for i in range(10,210,10)]})

df11 = pd.DataFrame({'acc':acc_dp_fd_1,'event':['acc']*20,'region':['dp_fd']*20, 'epoch':[i for i in range(10,210,10)]})
df12 = pd.DataFrame({'acc':acc_dp_fd_2,'event':['acc']*20,'region':['dp_fd']*20, 'epoch':[i for i in range(10,210,10)]})
df13 = pd.DataFrame({'acc':acc_dp_fd_3,'event':['acc']*20,'region':['dp_fd']*20, 'epoch':[i for i in range(10,210,10)]})
df14 = pd.DataFrame({'acc':acc_dp_fd_4,'event':['acc']*20,'region':['dp_fd']*20, 'epoch':[i for i in range(10,210,10)]})
df15 = pd.DataFrame({'acc':acc_dp_fd_5,'event':['acc']*20,'region':['dp_fd']*20, 'epoch':[i for i in range(10,210,10)]})

df16 = pd.DataFrame({'loss':loss_dp_fd_1,'event':['loss']*20,'region':['dp_fd']*20, 'epoch':[i for i in range(10,210,10)]})
df17 = pd.DataFrame({'loss':loss_dp_fd_2,'event':['loss']*20,'region':['dp_fd']*20, 'epoch':[i for i in range(10,210,10)]})
df18 = pd.DataFrame({'loss':loss_dp_fd_3,'event':['loss']*20,'region':['dp_fd']*20, 'epoch':[i for i in range(10,210,10)]})
df19 = pd.DataFrame({'loss':loss_dp_fd_4,'event':['loss']*20,'region':['dp_fd']*20, 'epoch':[i for i in range(10,210,10)]})
df20 = pd.DataFrame({'loss':loss_dp_fd_5,'event':['loss']*20,'region':['dp_fd']*20, 'epoch':[i for i in range(10,210,10)]})

# %%
result1 = pd.concat([df1,df2,df3,df4,df5,df11,df12,df13,df14,df15])
result2 = pd.concat([df6,df7,df8,df9,df10,df16,df17,df18,df19,df20])

# %%
sns.set_theme(style="darkgrid")

# %%
sns.lineplot(x="epoch", y="acc",
             hue="region",
             data=result1)
# confidence interval 로 그래프 표현
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='acc'>

# %%
# Load an example dataset with long-form data
#fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="epoch", y="acc",
             hue="region", ci = "sd",
             data=result1)
# 표준 편차로 그래프 표현
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='acc'>

# %%
sns.lineplot(x="epoch", y="loss",
             hue="region",
             data=result2)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='loss'>

# %%
# Plot the responses for different events and regions
sns.lineplot(x="epoch", y="loss",
             hue="region", ci = "sd",
             data=result2)
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='loss'>
